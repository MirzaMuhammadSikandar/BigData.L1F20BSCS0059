# %%
#-----ASSIGNMENT 1-----
import pandas as pd

# %%
df = pd.read_csv("jsrt_metadata.csv")

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
import numpy as np

# %%
df.replace("", np.nan, inplace = True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
mx=df['diagnosis'].value_counts().idxmax()
df['diagnosis'].replace(np.nan, mx, inplace=True)

# %%
df['diagnosis']
# Out:
# 0             lung cancer
# 1      pulmonary hematoma
# 2             lung cancer
# 3       Inflammatory mass
# 4             lung cancer
#               ...
# 242           lung cancer
# 243           lung cancer
# 244           lung cancer
# 245           lung cancer
# 246           lung cancer
# Name: diagnosis, Length: 247, dtype: object

# %%
plt.pyplot.title('DIAGNOSIS')
plt.pyplot.ylabel('Frequency')
plt.pyplot.xlabel('Diseases')
plt.pyplot.hist(df['diagnosis'], color = 'cyan', ec = 'red')
#-----Diagnosis Histogram------
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %%
#----Number of patients of each disease----
df["diagnosis"].value_counts()
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# lung cancer(large cell carcinoma)                   1
# susp. hamartoma                                     1
# metastasis of uterine cancer                        1
# organizing pneumonia                                1
# metastasis of ovarian cancer                        1
# metastatic lung cancer                              1
# lung canceror metastasis                            1
# pneumonia                                           1
# calcified granuloma                                 1
# lung cancer(adenosquamous carcinoma)                1
# lung cancer(small cell carcinoma)                   1
# susp.tuberculoma                                    1
# organiging pneumonia                                1
# susp. sclerosing hemangioma                         1
# susp. lung metastasis                               1
# Name: diagnosis, dtype: int64

# %%
#-----Diagnosis to Disease State------
df[["diagnosis","state"]].value_counts()
# Out:
# diagnosis                                       state
# lung cancer                                     non-nodule    93
#                                                 malignant     56
# lung cancer(adenocarcinoma)                     malignant     23
# tuberculoma                                     benign        14
# granuloma                                       benign         8
# lung cancer(bronchioloalveolar cell carcinoma)  malignant      7
# metastasis of colon cancer                      malignant      4
# unknown                                         benign         4
# inflammatory mass                               benign         4
# pulmonary tuberculosis                          benign         3
# lung abscess                                    benign         2
# Inflammatory mass                               benign         2
# susp. inflammatory mass                         benign         2
# sclerosing hemangioma                           benign         2
# pulmonary hematoma                              benign         2
# Cryptococcosis                                  benign         2
# hamartoma                                       benign         2
# lung cancer(squamous cell carcinoma)            malignant      2
# lung canceror metastasis                        malignant      1
# calcified granuloma                             benign         1
# susp.tuberculoma                                benign         1
# susp. sclerosing hemangioma                     benign         1
# susp. lung metastasis                           malignant      1
# lung cancer(adenosquamous carcinoma)            malignant      1
# susp. hamartoma                                 benign         1
# lung cancer(large cell carcinoma)               malignant      1
# metastasis of ovarian cancer                    malignant      1
# lung cancer(small cell carcinoma)               malignant      1
# pneumonia                                       benign         1
# organizing pneumonia                            benign         1
# metastatic lung cancer                          malignant      1
# metastasis of uterine cancer                    malignant      1
# organiging pneumonia                            benign         1
# dtype: int64

# %%
#-----PIE CHART : Diagnosis to State------
plt.pyplot.pie(df[['diagnosis','state']].value_counts(),shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23b19878a90>,
#   <matplotlib.patches.Wedge at 0x23b19887280>,
#   <matplotlib.patches.Wedge at 0x23b198879d0>,
#   <matplotlib.patches.Wedge at 0x23b19894160>,
#   <matplotlib.patches.Wedge at 0x23b198948b0>,
#   <matplotlib.patches.Wedge at 0x23b19894fd0>,
#   <matplotlib.patches.Wedge at 0x23b198a2790>,
#   <matplotlib.patches.Wedge at 0x23b198a2ee0>,
#   <matplotlib.patches.Wedge at 0x23b198b0670>,
#   <matplotlib.patches.Wedge at 0x23b198b0dc0>,
#   <matplotlib.patches.Wedge at 0x23b198437f0>,
#   <matplotlib.patches.Wedge at 0x23b198bdc70>,
#   <matplotlib.patches.Wedge at 0x23b198cb400>,
#   <matplotlib.patches.Wedge at 0x23b198cbb50>,
#   <matplotlib.patches.Wedge at 0x23b198d92e0>,
#   <matplotlib.patches.Wedge at 0x23b198d9a30>,
#   <matplotlib.patches.Wedge at 0x23b198e81c0>,
#   <matplotlib.patches.Wedge at 0x23b198e8910>,
#   <matplotlib.patches.Wedge at 0x23b198f50a0>,
#   <matplotlib.patches.Wedge at 0x23b198f57f0>,
#   <matplotlib.patches.Wedge at 0x23b198f5f40>,
#   <matplotlib.patches.Wedge at 0x23b199026d0>,
#   <matplotlib.patches.Wedge at 0x23b19902e20>,
#   <matplotlib.patches.Wedge at 0x23b199115b0>,
#   <matplotlib.patches.Wedge at 0x23b19911d00>,
#   <matplotlib.patches.Wedge at 0x23b1991d490>,
#   <matplotlib.patches.Wedge at 0x23b1991dbe0>,
#   <matplotlib.patches.Wedge at 0x23b1992a370>,
#   <matplotlib.patches.Wedge at 0x23b1992aac0>,
#   <matplotlib.patches.Wedge at 0x23b19939250>,
#   <matplotlib.patches.Wedge at 0x23b199399a0>,
#   <matplotlib.patches.Wedge at 0x23b19864d90>,
#   <matplotlib.patches.Wedge at 0x23b199466d0>],
#  [Text(0.4160997880601955, 1.0182637017866543, ''),
#   Text(-1.0977763719436746, 0.0699073472689613, ''),
#   Text(-0.6476951466668902, -0.8890956062112532, ''),
#   Text(-0.1741504033155111, -1.0861268972937945, ''),
#   Text(0.1325903404163534, -1.091979762462783, ''),
#   Text(0.3372563642798493, -1.0470234690553684, ''),
#   Text(0.4799714817413008, -0.9897612725880217, ''),
#   Text(0.5780254272429179, -0.9358881372582102, ''),
#   Text(0.6700999667671853, -0.8723336715607264, ''),
#   Text(0.7450097309069345, -0.8092962997901184, ''),
#   Text(0.7949362176160618, -0.7603133629775749, ''),
#   Text(0.8325726606439009, -0.7189038633561069, ''),
#   Text(0.8680545649138726, -0.6756339780770263, ''),
#   Text(0.901290110046126, -0.6306156813250381, ''),
#   Text(0.9321932888084875, -0.5839654718392313, ''),
#   Text(0.9606841296867188, -0.5358040714366326, ''),
#   Text(0.9866889038354972, -0.4862561126072403, ''),
#   Text(1.010140315874562, -0.435449815988984, ''),
#   Text(1.0260164705727877, -0.39659828808677444, ''),
#   Text(1.0357721034648881, -0.37037298724923423, ''),
#   Text(1.0448575329321228, -0.34390803403671427, ''),
#   Text(1.053266880185205, -0.31722055277822914, ''),
#   Text(1.0609947038984693, -0.29032781179108497, ''),
#   Text(1.068036003730719, -0.26324721220730035, ''),
#   Text(1.0743862235607313, -0.23599627671408402, ''),
#   Text(1.0800412544353253, -0.20859263821566004, ''),
#   Text(1.0849974372280897, -0.18105402842377658, ''),
#   Text(1.0892515650070453, -0.15339826638428047, ''),
#   Text(1.0928008851097117, -0.12564324694718182, ''),
#   Text(1.0956431009242373, -0.09780692918766887, ''),
#   Text(1.0977763733754364, -0.06990732478556444, ''),
#   Text(1.0991993221147769, -0.041962486370749334, ''),
#   Text(1.0999110264135428, -0.013990495842078806, '')])

# %%
#-----Diagnosis to Gender------
df[["diagnosis","gender"]].value_counts()
# Out:
# diagnosis                                       gender
# lung cancer                                     Male      75
#                                                 Female    74
# lung cancer(adenocarcinoma)                     Female    15
# tuberculoma                                     Male       9
# lung cancer(adenocarcinoma)                     Male       8
# granuloma                                       Male       6
# tuberculoma                                     Female     5
# unknown                                         Female     4
# lung cancer(bronchioloalveolar cell carcinoma)  Female     4
# pulmonary tuberculosis                          Male       3
# lung cancer(bronchioloalveolar cell carcinoma)  Male       3
# metastasis of colon cancer                      Female     3
# Cryptococcosis                                  Female     2
# hamartoma                                       Female     2
# inflammatory mass                               Male       2
#                                                 Female     2
# granuloma                                       Female     2
# sclerosing hemangioma                           Female     2
# lung cancer(squamous cell carcinoma)            Male       2
# Inflammatory mass                               Female     2
# susp. inflammatory mass                         Male       1
# susp. hamartoma                                 Male       1
# susp. inflammatory mass                         Female     1
# susp. sclerosing hemangioma                     Female     1
# susp. lung metastasis                           Female     1
# pulmonary hematoma                              Female     1
# susp.tuberculoma                                Male       1
# calcified granuloma                             Male       1
# pulmonary hematoma                              Male       1
# lung abscess                                    Male       1
# pneumonia                                       Female     1
# lung abscess                                    Female     1
# organiging pneumonia                            Male       1
# metastatic lung cancer                          Female     1
# metastasis of uterine cancer                    Female     1
# metastasis of ovarian cancer                    Female     1
# metastasis of colon cancer                      Male       1
# lung canceror metastasis                        Female     1
# lung cancer(small cell carcinoma)               Male       1
# lung cancer(large cell carcinoma)               Male       1
# lung cancer(adenosquamous carcinoma)            Male       1
# organizing pneumonia                            Female     1
# dtype: int64

# %%
#-----PIE CHART : Diagnosis to Gender------
plt.pyplot.pie(df[['diagnosis','gender']].value_counts(),shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23b1972b9a0>,
#   <matplotlib.patches.Wedge at 0x23b1973b190>,
#   <matplotlib.patches.Wedge at 0x23b1973b8e0>,
#   <matplotlib.patches.Wedge at 0x23b1973bfd0>,
#   <matplotlib.patches.Wedge at 0x23b197487c0>,
#   <matplotlib.patches.Wedge at 0x23b19748f10>,
#   <matplotlib.patches.Wedge at 0x23b197576a0>,
#   <matplotlib.patches.Wedge at 0x23b19757df0>,
#   <matplotlib.patches.Wedge at 0x23b19764580>,
#   <matplotlib.patches.Wedge at 0x23b19764cd0>,
#   <matplotlib.patches.Wedge at 0x23b1970c820>,
#   <matplotlib.patches.Wedge at 0x23b19771b80>,
#   <matplotlib.patches.Wedge at 0x23b19780310>,
#   <matplotlib.patches.Wedge at 0x23b19780a60>,
#   <matplotlib.patches.Wedge at 0x23b1978e1f0>,
#   <matplotlib.patches.Wedge at 0x23b1978e940>,
#   <matplotlib.patches.Wedge at 0x23b1979b0d0>,
#   <matplotlib.patches.Wedge at 0x23b1979b820>,
#   <matplotlib.patches.Wedge at 0x23b1979bf70>,
#   <matplotlib.patches.Wedge at 0x23b197a9700>,
#   <matplotlib.patches.Wedge at 0x23b197a9e50>,
#   <matplotlib.patches.Wedge at 0x23b197b75e0>,
#   <matplotlib.patches.Wedge at 0x23b197b7d30>,
#   <matplotlib.patches.Wedge at 0x23b197c44c0>,
#   <matplotlib.patches.Wedge at 0x23b197c4c10>,
#   <matplotlib.patches.Wedge at 0x23b197d13a0>,
#   <matplotlib.patches.Wedge at 0x23b197d1af0>,
#   <matplotlib.patches.Wedge at 0x23b197e0280>,
#   <matplotlib.patches.Wedge at 0x23b197e09d0>,
#   <matplotlib.patches.Wedge at 0x23b197ea160>,
#   <matplotlib.patches.Wedge at 0x23b197ea8e0>,
#   <matplotlib.patches.Wedge at 0x23b197eafd0>,
#   <matplotlib.patches.Wedge at 0x23b197fd7c0>,
#   <matplotlib.patches.Wedge at 0x23b197fdf10>,
#   <matplotlib.patches.Wedge at 0x23b198066a0>,
#   <matplotlib.patches.Wedge at 0x23b19806df0>,
#   <matplotlib.patches.Wedge at 0x23b19815580>,
#   <matplotlib.patches.Wedge at 0x23b19815cd0>,
#   <matplotlib.patches.Wedge at 0x23b19823460>,
#   <matplotlib.patches.Wedge at 0x23b19823bb0>,
#   <matplotlib.patches.Wedge at 0x23b19831340>,
#   <matplotlib.patches.Wedge at 0x23b19831a90>],
#  [Text(0.6363346275672915, 0.8972615236143789, ''),
#   Text(-1.0532668978197752, 0.3172204942261888, ''),
#   Text(-0.7346562374226806, -0.8187064265143827, ''),
#   Text(-0.4546412912955383, -1.0016492880490286, ''),
#   Text(-0.22915892112618208, -1.0758653209711169, ''),
#   Text(-0.03497125507116722, -1.0994439555151265, ''),
#   Text(0.1186912064393753, -1.0935777967360008, ''),
#   Text(0.24282413163038521, -1.0728636637979447, ''),
#   Text(0.35054591715721556, -1.0426492986447584, ''),
#   Text(0.4418650615883634, -1.0073506178821314, ''),
#   Text(0.5173793659026957, -0.9707309574429595, ''),
#   Text(0.5898820050620465, -0.9284606723518126, ''),
#   Text(0.6476952299100254, -0.8890955455696534, ''),
#   Text(0.6920712843575617, -0.8550072148044573, ''),
#   Text(0.7346563907283228, -0.8187062889474065, ''),
#   Text(0.7753403469144082, -0.780286707849522, ''),
#   Text(0.8140178706208652, -0.739847894036249, ''),
#   Text(0.8505888718161299, -0.6974944954209773, ''),
#   Text(0.8849587117458758, -0.6533361144962676, ''),
#   Text(0.917038447840006, -0.6074870247035674, ''),
#   Text(0.9395452008568503, -0.5720618983526704, ''),
#   Text(0.953791771239662, -0.5479792488000879, ''),
#   Text(0.9674211841323701, -0.5235420255260537, ''),
#   Text(0.9804246205301289, -0.49876604080305315, ''),
#   Text(0.9927936664704659, -0.47366732610148415, ''),
#   Text(1.0045203184775933, -0.44826212171638424, ''),
#   Text(1.0155969887411123, -0.4225668662590398, ''),
#   Text(1.0260165100257577, -0.3965981860202648, ''),
#   Text(1.0357721403090063, -0.3703728842122498, ''),
#   Text(1.0448575671435487, -0.34390793009592663, ''),
#   Text(1.053266911741802, -0.31722044800089294, ''),
#   Text(1.0609947327798186, -0.2903277062449971, ''),
#   Text(1.068036029918133, -0.2632471059607552, ''),
#   Text(1.074386247037265, -0.23599616983582916, ''),
#   Text(1.080041275185788, -0.2085925307748517, ''),
#   Text(1.0849974552390549, -0.18105392048993413, ''),
#   Text(1.0892515802668588, -0.1533981580272442, ''),
#   Text(1.0928008976084993, -0.1256431382370649, ''),
#   Text(1.0956431106539117, -0.09780682019481292, ''),
#   Text(1.0977763803297018, -0.06990721558049502, ''),
#   Text(1.0991993262891335, -0.04196237702412735, ''),
#   Text(1.0999110278052897, -0.013990386424657735, '')])
